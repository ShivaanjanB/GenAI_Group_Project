# %% [markdown]
# <a href="https://colab.research.google.com/github/ShivaanjanB/GenAI_RAG/blob/main/GenAI_Task_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: Shivaanjan Bhattacharjee

# %% [markdown]
# Through these tasks, I learned that different problems require very specific prompting strategies to get accurate results. In Task 7, I saw firsthand how using specific Personas such as a Skeptic could pierce through corporate gloss and reveal hidden biases in financial reports that a neutral prompt might accept as fact. In Task 8, I realized that generic prompts often fail to distinguish between complex business models. It was only by applying Structured Constraints via the Atom of Thought technique that I could isolate the unique structural risks of Block compared to PayPal. Finally, Task 9 taught me the most important rule of all which is that LLMs cannot be trusted with calendar math. For any task involving precise calculations or dates, I must use Code Execution tools to ensure the output is reliable rather than relying on the model making a guess.

# %% [markdown]
# The Prompt:
#
# "You are a financial auditor. Do not perform the math yourself. Write and execute a Python script to calculate the loan amortization.
#
# Use the datetime library to calculate the exact number of days between the payment dates listed below.
#
# Ensure you account for the 2024 Leap Year (Feb 29).
#
# Formula: Daily_Interest = Balance * (0.12 / 365) * Days_Elapsed.
#
# Inputs: Start Jan 1, 2024 ($100k).
#
# Payments of $5,000 on Jan 31, Feb 29, Mar 31."

# %% [markdown]
# Executive Summary
# Audit Findings: Verified
# The manual audit confirms the bank's calculations are correct. By using a programmatic verification tool, we established that the loan correctly accounted for the 29-day accrual period in February 2024. A standard approximation would have undercharged interest by excluding the leap day. The remaining balance as of March 31, 2024, is $87,838.03.
